# %%
import numpy as np
import matplotlib.pyplot as plt
import os
import cv2
import platform
import random
import keras
from keras.models import Sequential
from keras.layers import Activation, Flatten, Dense, Dropout, Conv2D, MaxPooling2D
# Out:
# Using TensorFlow backend.

# %%
# Verify which machine this program is running on

DATADIR = ""

# Checking which computer is running this program. (Either running on macOS or Ubuntu)
if("Linux" == platform.system()):
        DATADIR = "/home/ragib/Documents/dogs-vs-cats"
        print("Running on Linux and the data path is : " + DATADIR)
else:
        DATADIR = "/Users/ragibahashan/Computer Vision/dogs-vs-cats"
        print("Running on macOS and the data path is : " + DATADIR)
# Out:
# Running on macOS and the data path is : /Users/ragibahashan/Computer Vision/dogs-vs-cats

# %%
training_path = DATADIR + "/train"

list_all_training_images = os.listdir(training_path)

# Shuffle list
random.seed(30)
random.shuffle(list_all_training_images)
print("There are", len(list_all_training_images), "training examples (images) of cats and dogs.")


# First test. Output an image from the list using cv2.
image = list_all_training_images[0]
image_test = cv2.imread(os.path.join(training_path, image), cv2.IMREAD_GRAYSCALE)
plt.imshow(image_test, cmap = "gray")
plt.show()
# Out:
# There are 25000 training examples (images) of cats and dogs.

# %%
# Need to rescale it to a square & smaller resolution format in order to feed it into the neural net.
resolution = 100

test_image = cv2.resize(image_test, (resolution,resolution))
plt.imshow(test_image, cmap = "gray")
plt.show()

# %% [markdown]
# # Now that we've correctly imported our cats and dogs images, it's time to get create our training data.

# %%
training_data = []
CAT = 0
DOG = 1

cats = 0
dogs = 0
size_data = len(list_all_training_images)

for image in list_all_training_images:
    if(image.find("cat") == CAT):
        current_image = cv2.imread(os.path.join(training_path, image), cv2.IMREAD_GRAYSCALE)
        current_image = cv2.resize(current_image, (resolution,resolution))
        training_data.append([current_image,CAT])
        cats += 1
    else:
        current_image = cv2.imread(os.path.join(training_path, image), cv2.IMREAD_GRAYSCALE)
        current_image = cv2.resize(current_image, (resolution,resolution))
        training_data.append([current_image,DOG])
        dogs += 1
    if (dogs+cats)%1000 == 0:
            print(dogs+cats , "/", size_data, "    ", ((dogs+cats)/size_data)*100,"%")
        
print("The number of images of cats is equal to the number of images of dogs in our training data: ", cats == dogs)
print("Number of images of cats:", cats)
print("Number of images of dogs:" , dogs)
# Out:
# 1000 / 25000      4.0 %
# 2000 / 25000      8.0 %
# 3000 / 25000      12.0 %
# 4000 / 25000      16.0 %
# 5000 / 25000      20.0 %
# 6000 / 25000      24.0 %
# 7000 / 25000      28.000000000000004 %
# 8000 / 25000      32.0 %
# 9000 / 25000      36.0 %
# 10000 / 25000      40.0 %
# 11000 / 25000      44.0 %
# 12000 / 25000      48.0 %
# 13000 / 25000      52.0 %
# 14000 / 25000      56.00000000000001 %
# 15000 / 25000      60.0 %
# 16000 / 25000      64.0 %
# 17000 / 25000      68.0 %
# 18000 / 25000      72.0 %
# 19000 / 25000      76.0 %
# 20000 / 25000      80.0 %
# 21000 / 25000      84.0 %
# 22000 / 25000      88.0 %
# 23000 / 25000      92.0 %
# 24000 / 25000      96.0 %
# 25000 / 25000      100.0 %
# The number of images of cats is equal to the number of images of dogs in our training data:  True
# Number of images of cats: 12500
# Number of images of dogs: 12500

# %%
# Verify our list.
for i in range(4):
    if(training_data[i][1] == CAT):
        plt.imshow(training_data[i][0], cmap = "gray")
        print("CAT")
    else:
        plt.imshow(training_data[i][0], cmap = "gray")
        print("DOG")
    plt.show()
# Out:
# CAT
# DOG
# CAT
# CAT

# %%
x_train = []
y_train = []

for features, label in training_data:
        x_train.append(features)
        y_train.append(label)

# %%
print("This is a cat:" ,y_train[4] == CAT)
plt.imshow(x_train[4], cmap = "gray")
plt.show()
# Out:
# This is a cat: False

# %%
print(x_train[0].shape)
# Out:
# (100, 100)

# %%
x_train = np.array(x_train)

# %%
x_train.reshape(-1, x_train.shape[0], x_train.shape[1], 1)
# Out:
# array([[[[  4],
#          [  4],
#          [  4],
#          ...,
#          [  6],
#          [  4],
#          [  3]],
#
#         [[  4],
#          [  4],
#          [  2],
#          ...,
#          [  7],
#          [  6],
#          [  8]],
#
#         [[  4],
#          [  4],
#          [  3],
#          ...,
#          [  6],
#          [  8],
#          [  7]],
#
#         ...,
#
#         [[  9],
#          [  9],
#          [ 10],
#          ...,
#          [ 49],
#          [ 48],
#          [ 48]],
#
#         [[  9],
#          [  4],
#          [  7],
#          ...,
#          [ 48],
#          [ 46],
#          [ 44]],
#
#         [[  8],
#          [  6],
#          [  7],
#          ...,
#          [ 46],
#          [ 45],
#          [ 44]]],
#
#
#        [[[126],
#          [131],
#          [124],
#          ...,
#          [111],
#          [ 59],
#          [ 57]],
#
#         [[131],
#          [129],
#          [124],
#          ...,
#          [109],
#          [ 85],
#          [ 77]],
#
#         [[128],
#          [125],
#          [126],
#          ...,
#          [ 55],
#          [ 53],
#          [108]],
#
#         ...,
#
#         [[164],
#          [133],
#          [101],
#          ...,
#          [123],
#          [123],
#          [129]],
#
#         [[107],
#          [107],
#          [ 99],
#          ...,
#          [112],
#          [117],
#          [117]],
#
#         [[137],
#          [121],
#          [110],
#          ...,
#          [116],
#          [116],
#          [116]]],
#
#
#        [[[ 98],
#          [120],
#          [109],
#          ...,
#          [109],
#          [113],
#          [126]],
#
#         [[112],
#          [138],
#          [121],
#          ...,
#          [112],
#          [131],
#          [142]],
#
#         [[120],
#          [115],
#          [111],
#          ...,
#          [130],
#          [141],
#          [140]],
#
#         ...,
#
#         [[108],
#          [109],
#          [ 79],
#          ...,
#          [ 48],
#          [ 40],
#          [ 75]],
#
#         [[102],
#          [101],
#          [ 35],
#          ...,
#          [ 48],
#          [ 73],
#          [ 82]],
#
#         [[106],
#          [ 98],
#          [ 20],
#          ...,
#          [ 63],
#          [ 67],
#          [ 77]]],
#
#
#        ...,
#
#
#        [[[201],
#          [204],
#          [204],
#          ...,
#          [172],
#          [169],
#          [168]],
#
#         [[205],
#          [204],
#          [206],
#          ...,
#          [172],
#          [171],
#          [169]],
#
#         [[202],
#          [203],
#          [203],
#          ...,
#          [170],
#          [171],
#          [171]],
#
#         ...,
#
#         [[216],
#          [251],
#          [250],
#          ...,
#          [ 56],
#          [ 57],
#          [ 59]],
#
#         [[253],
#          [253],
#          [253],
#          ...,
#          [ 56],
#          [ 51],
#          [ 53]],
#
#         [[253],
#          [253],
#          [253],
#          ...,
#          [ 56],
#          [ 54],
#          [ 53]]],
#
#
#        [[[ 94],
#          [ 99],
#          [ 97],
#          ...,
#          [ 51],
#          [ 43],
#          [ 37]],
#
#         [[ 86],
#          [ 96],
#          [100],
#          ...,
#          [ 54],
#          [ 57],
#          [ 45]],
#
#         [[ 94],
#          [ 90],
#          [ 93],
#          ...,
#          [ 58],
#          [ 61],
#          [ 56]],
#
#         ...,
#
#         [[255],
#          [255],
#          [255],
#          ...,
#          [198],
#          [229],
#          [241]],
#
#         [[255],
#          [255],
#          [255],
#          ...,
#          [216],
#          [232],
#          [237]],
#
#         [[255],
#          [255],
#          [255],
#          ...,
#          [222],
#          [232],
#          [251]]],
#
#
#        [[[255],
#          [255],
#          [255],
#          ...,
#          [255],
#          [255],
#          [255]],
#
#         [[255],
#          [255],
#          [255],
#          ...,
#          [255],
#          [255],
#          [255]],
#
#         [[255],
#          [255],
#          [255],
#          ...,
#          [255],
#          [255],
#          [255]],
#
#         ...,
#
#         [[ 54],
#          [ 56],
#          [ 58],
#          ...,
#          [ 98],
#          [ 52],
#          [ 13]],
#
#         [[ 52],
#          [ 54],
#          [ 56],
#          ...,
#          [119],
#          [104],
#          [ 71]],
#
#         [[ 51],
#          [ 53],
#          [ 54],
#          ...,
#          [119],
#          [114],
#          [102]]]], dtype=uint8)

# %%
print(x_train.shape)
# Out:
# (25000, 100, 100)

# %%
x_train = x_train/255 # Normalize Data

# %%
y_train = np.array(y_train)
print(x_train.shape)
print(y_train.shape)

img_rows = x_train[0].shape[1]
img_cols = x_train[0].shape[1]

input_shape = (img_rows, img_cols, 1)

x_train = x_train.reshape(x_train.shape[0], img_rows, img_cols, 1)

print(x_train.shape)
# Out:
# (25000, 100, 100, 1)
# (25000,)
# (25000, 100, 100, 1)

# %%
model = Sequential()

model.add(Conv2D(64, kernel_size =(3,3), input_shape = input_shape))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Conv2D(64, kernel_size =(3,3)))
model.add(Activation("relu"))
model.add(MaxPooling2D(pool_size=(2,2)))

model.add(Flatten())
model.add(Dense(64))
model.add(Dense(1))

model.add(Activation("sigmoid"))

model.summary()
# Out:
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv2d_3 (Conv2D)            (None, 98, 98, 64)        640
# _________________________________________________________________
# activation_4 (Activation)    (None, 98, 98, 64)        0
# _________________________________________________________________
# max_pooling2d_3 (MaxPooling2 (None, 49, 49, 64)        0
# _________________________________________________________________
# conv2d_4 (Conv2D)            (None, 47, 47, 64)        36928
# _________________________________________________________________
# activation_5 (Activation)    (None, 47, 47, 64)        0
# _________________________________________________________________
# max_pooling2d_4 (MaxPooling2 (None, 23, 23, 64)        0
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 33856)             0
# _________________________________________________________________
# dense_3 (Dense)              (None, 64)                2166848
# _________________________________________________________________
# dense_4 (Dense)              (None, 1)                 65
# _________________________________________________________________
# activation_6 (Activation)    (None, 1)                 0
# =================================================================
# Total params: 2,204,481
# Trainable params: 2,204,481
# Non-trainable params: 0
# _________________________________________________________________

# %%
model.compile(loss = "binary_crossentropy", optimizer = "adam", metrics = ['accuracy'])

# %%
model.fit(x_train, y_train, epochs = 5, validation_split = 0.2)
